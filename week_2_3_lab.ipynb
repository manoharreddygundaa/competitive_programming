# %% [markdown]
# <a href="https://colab.research.google.com/github/manoharreddygundaa/competitive_programming/blob/main/week_2_3_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.setrecursionlimit(10**7)

memo = {}

def fibonacci(n):
    if n in memo:
        return memo[n]

    if n <= 1:
        return n

    memo[n] = fibonacci(n-1) + fibonacci(n-2)
    return memo[n]


n = int(input().strip())
print(fibonacci(n))
# Out:
# 10
# 55

# %%
n, W = map(int, input().split())

val = []
wt = []

for _ in range(n):
    v, w = map(int, input().split())
    val.append(v)
    wt.append(w)

dp = [0]*(W+1)

for i in range(n):
    for w in range(W, wt[i]-1, -1):
        dp[w] = max(dp[w], val[i] + dp[w-wt[i]])

print(dp[W])
# Out:
# 3 50
# 60 10
# 100 20
# 120 30
# 220

# %%
s1 = input().strip()
s2 = input().strip()

n, m = len(s1), len(s2)

dp = [[0]*(m+1) for _ in range(n+1)]

for i in range(1, n+1):
    for j in range(1, m+1):
        if s1[i-1] == s2[j-1]:
            dp[i][j] = 1 + dp[i-1][j-1]
        else:
            dp[i][j] = max(dp[i-1][j], dp[i][j-1])

print(dp[n][m])
# Out:
# AGGTAB
# GXTXAYB
# 4

# %%
n = int(input())
coins = list(map(int, input().split()))
amount = int(input())

INF = 10**9
dp = [INF]*(amount+1)
dp[0] = 0

for coin in coins:
    for x in range(coin, amount+1):
        dp[x] = min(dp[x], 1 + dp[x-coin])

print(dp[amount] if dp[amount] != INF else -1)
# Out:
# 3
# 1 3 4
# 6
# 2

# %%
n = int(input())
arr = list(map(int, input().split()))

dp = [[0]*n for _ in range(n)]

for length in range(2, n):
    for i in range(1, n-length+1):
        j = i + length - 1
        dp[i][j] = float('inf')

        for k in range(i, j):
            cost = dp[i][k] + dp[k+1][j] + arr[i-1]*arr[k]*arr[j]
            dp[i][j] = min(dp[i][j], cost)

print(dp[1][n-1])
# Out:
# 4
# 10 20 30 40
# 18000
